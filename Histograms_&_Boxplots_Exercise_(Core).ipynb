# %% [markdown]
# <a href="https://colab.research.google.com/github/kellianneyang/bootcamp-assignments/blob/main/Histograms_%26_Boxplots_Exercise_(Core).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Name:** Kellianne Yang

# %% [markdown]
# # **Histograms & Boxplots Exercise (Core)**

# %% [markdown]
# For this task, you will use the insurance dataset.

# %%
import pandas as pd
url = 'https://docs.google.com/spreadsheets/d/e/2PACX-1vS8EOvOoG2CKLd7KBQ2fetTPXDBioP3qjzzf45xjxxyDlC_WLeZdXi_k8r9UkWsRd9KiyPQXTwchi1C/pub?output=csv'
df = pd.read_csv(url)
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We are going to explore the distribution of the BMI data.

# %% [markdown]
# ## Part 1: Histogram

# %% [markdown]
# Create a histogram showing the distribution of BMI for the entire dataset.
#
# - Use 20 bins
# - Add black edge color to the bins
# - Add a title (Distribution of BMI)
# - Add an x-axis label (BMI)
# - Add a y-axis label (Number of Individuals)

# %%
# import libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# create histograph with bmi data
# bins = 20
# black around bins
ax1 = df['bmi'].hist(bins = 20, 
              edgecolor = 'black')

# title: 'Distribution of BMI'
ax1.set_title('Distribution of BMI')

# x-axis label: 'BMI'
ax1.set_xlabel('BMI')

# y-axis label: 'Number of Individuals'
ax1.set_ylabel('Number of Individuals');

# %% [markdown]
# ## Part 2: Boxplots

# %% [markdown]
# Create side-by-side boxplots comparing the distribution of BMI when grouped by region.
#
# - Use Seaborn to create the boxplots
# - Add a title (BMI by region)

# %%
ax2 = sns.boxplot(x = 'bmi', y = 'region', data = df)
ax2.set_title('BMI by region');

# %% [markdown]
# Download and submit your notebook.
